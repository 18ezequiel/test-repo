# %%
import sys
from pyspark.context import SparkContext
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.sql import SparkSession
import datetime
from pyspark.sql.functions import expr
from pyspark.sql.functions import col
from pyspark.sql.functions import lower


# Definimos el mapping que aplicará la transformación a la columna 'time'
schema = StructType([
            StructField("name", StringType(), True),
            StructField("address", StringType(), True),
            StructField("gmap_id", StringType(), True),
            StructField("description", StringType(), True),
            StructField("latitude", FloatType(), True),
            StructField("longitude", FloatType(), True),
            StructField("category", StringType(), True),
            StructField("num_of_reviews", IntegerType(), True),
            StructField("avg_rating", FloatType(), True),
            StructField("price", FloatType(), True),
            StructField("hours", StringType(), True),
            StructField("MISC", StringType(), True)
            ])


spark = SparkSession.builder.appName("MiApp").getOrCreate()

df = spark.read.csv("/home/ezequiell/Descargas/metada_newyork.csv", header=True, schema=schema)
df.printSchema()
df.show()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- address: string (nullable = true)
#  |-- gmap_id: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- latitude: float (nullable = true)
#  |-- longitude: float (nullable = true)
#  |-- category: string (nullable = true)
#  |-- num_of_reviews: integer (nullable = true)
#  |-- avg_rating: float (nullable = true)
#  |-- price: float (nullable = true)
#  |-- hours: string (nullable = true)
#  |-- MISC: string (nullable = true)
#
# 23/02/21 16:46:56 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 15, schema size: 12
# CSV file: file:///home/ezequiell/Descargas/metada_newyork.csv
# +--------------------+--------------------+--------------------+--------------------+---------+----------+--------------------+--------------+----------+-----+--------------------+--------------------+
# |                name|             address|             gmap_id|         description| latitude| longitude|            category|num_of_reviews|avg_rating|price|               hours|                MISC|
# +--------------------+--------------------+--------------------+--------------------+---------+----------+--------------------+--------------+----------+-----+--------------------+--------------------+
# |Shelter Cove Apar...|Shelter Cove Apar...|0x405b94b45e01bc0...|                null|42.806812|  -73.7395|['Apartment renta...|          null|      36.0| null|[['Saturday', '10...|{'Health & safety...|
# |       Mcneillys Pub|Mcneillys Pub, 30...|0x405bccedd9871fd...|                null|43.058044| -76.12334|             ['Pub']|          null|      76.0| null|[['Monday', '10AM...|{'Service options...|
# |          Mellow Mug|Mellow Mug, 616 P...|0x405bccf4faffedd...|                null| 43.06222|-77.479034|['Coffee shop', '...|          null|      88.0| null|[['Wednesday', '7...|{'Service options...|
# |New Holland Resid...|New Holland Resid...|0x4066087f183b65c...|                null|40.804264| -73.95458|['Corporate office']|          null|      53.0| null|[['Friday', '9AM–...|                null|
# |             Lincare|Lincare, 1437 NY-...|0x406790f7e0a67f8...|                null|41.484787| -74.07281|['Oxygen equipmen...|          null|      47.0| null|[['Thursday', '8A...|                null|
# |North Country Gol...|North Country Gol...|0x4cc987f789377c6...|                null| 44.98968| -73.39465|     ['Golf course']|          null|      47.0| null|[['Friday', '7:30...|{'Accessibility':...|
# |             Dunkin'|Dunkin', 1038 Sta...|0x4cca29c04f91cd3...|Long-running chai...| 44.98149|-73.459274|['Coffee shop', '...|          null|     135.0| null|[['Monday', '5AM–...|{'Service options...|
# |       CODYS GROCERY|CODYS GROCERY, 29...|0x4cca36d5b2fee80...|                null| 44.78085|-73.556755|     ['Gas station']|          null|      16.0| null|                null|                null|
# |Pawfection Pet Gr...|Pawfection Pet Gr...|0x4cca380999e7461...|                null| 44.70508|-73.527214|     ['Pet groomer']|          null|      28.0| null|                null|{'Accessibility':...|
# |Homestead Restaurant|Homestead Restaur...|0x4cca3876b359eea...|                null|44.705822| -73.51141|['Breakfast resta...|          null|      78.0| null|[['Tuesday', '6AM...|{'Service options...|
# |     Body Art Tattoo|Body Art Tattoo, ...|0x4cca38a95dded20...|                null| 44.69608|-73.453094|['Tattoo shop', '...|          null|      98.0| null|[['Tuesday', '11A...|{'Service options...|
# |The Corner Stone ...|The Corner Stone ...|0x4cca38ae9559973...|                null|44.698368| -73.45281| ['Used book store']|          null|      68.0| null|[['Monday', 'Clos...|{'Service options...|
# |  Meron's Restaurant|Meron's Restauran...|0x4cca38bd56e9b69...|                null|44.704376| -73.46721|['Bar', 'American...|          null|      83.0| null|[['Friday', '3PM–...|{'Service options...|
# |StoneWorks Massag...|StoneWorks Massag...|0x4cca38c819478d0...|                null|44.727478|  -73.4345|['Massage therapi...|          null|      44.0| null|[['Sunday', '8:45...|{'Health & safety...|
# |   RR Charlebois Inc|RR Charlebois Inc...|0x4cca38ecaf94c21...|                null|44.714264| -73.46887|    ['Truck dealer']|          null|      27.0| null|[['Monday', '7:30...|{'Service options...|
# |Ausable Marsh Wil...|Ausable Marsh Wil...|0x4cca428e3258bf2...|Conservation wetl...|44.568447| -73.43351|['Park', 'Tourist...|          null|      68.0| null|                null|                null|
# |     New Impressions|New Impressions, ...|0x4cca449aa1295e4...|                null| 44.57926| -73.52843|['Beauty salon', ...|          null|      28.0| null|[['Saturday', '9A...|{'Health & safety...|
# |Champlain Valley ...|Champlain Valley ...|0x4cca4762a84f4f3...|                null|44.696167| -73.49234|['Veterinarian', ...|          null|      76.0| null|[['Saturday', '8A...|{'Accessibility':...|
# |Little Caesars Pizza|Little Caesars Pi...|0x4cca477e599e607...|                null|44.701073| -73.49436|['Pizza restauran...|          null|      54.0| null|[['Saturday', '12...|{'Service options...|
# |           CosmoProf|CosmoProf, 494 NY...|0x4cca477fa3752e2...|                null|44.696938| -73.49623|['Beauty supply s...|          null|      15.0| null|[['Tuesday', '8AM...|{'Service options...|
# +--------------------+--------------------+--------------------+--------------------+---------+----------+--------------------+--------------+----------+-----+--------------------+--------------------+
# only showing top 20 rows

# %%
# filtramos solo el rubro de restaurantes que es en lo que se enfocara el sistema de recomendacion
df = df.filter(lower(df["category"]).like("%restaurant%"))


df2 = df.select("*", from_json("MISC", "map<string,string>").alias("mapa_misc"))

# Usar explode para crear una fila por cada clave del diccionario
df3 = df2.select("*", explode("mapa_misc").alias("clave", "valor"))

df3 = df3.withColumn("clave", regexp_replace("clave", " ", "_"))

# Usar pivot para convertir las claves en columnas
df4 = df3.groupBy("gmap_id").pivot("clave").agg({"valor": "first"})

#df4.printSchema()

# Unir el resultado de pivot con las columnas originales
df_final = df3.join(df4, on="gmap_id")

#df_final.printSchema()

df = df_final.select('gmap_id', 'name', 'address', 'latitude', 'longitude', 'num_of_reviews', 'avg_rating', 'category', 'Dining_options', 'Service_options', 'Payments')

df = df \
    .select(col("gmap_id").alias("gmap_id"), \
            col("name").alias("name"), \
            col("address").alias("address"), \
            col("latitude").alias("latitude"), \
            col("longitude").alias("longitude"), \
            col("num_of_reviews").alias("num_reviews"), \
            col("avg_rating").alias("avg_rating"), \
            col("category").alias("category"), \
            col("Dining_options").alias("dining_options"), \
            col("Service_options").alias("service_options"), \
            col("Payments").alias("payments")) \
    .dropDuplicates()

df.printSchema()
df.show()
# Out:
# root
#  |-- gmap_id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- address: string (nullable = true)
#  |-- latitude: float (nullable = true)
#  |-- longitude: float (nullable = true)
#  |-- num_reviews: integer (nullable = true)
#  |-- avg_rating: float (nullable = true)
#  |-- category: string (nullable = true)
#  |-- dining_options: string (nullable = true)
#  |-- service_options: string (nullable = true)
#  |-- payments: string (nullable = true)
#
# 23/02/21 16:46:59 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: name, address, gmap_id, latitude, longitude, category, avg_rating, num_of_reviews, MISC
#  Schema: name, address, gmap_id, latitude, longitude, category, num_of_reviews, avg_rating, MISC
# Expected: num_of_reviews but found: avg_rating
# CSV file: file:///home/ezequiell/Descargas/metada_newyork.csv
# +--------------------+--------------------+--------------------+---------+----------+-----------+----------+--------------------+--------------------+--------------------+--------------------+
# |             gmap_id|                name|             address| latitude| longitude|num_reviews|avg_rating|            category|      dining_options|     service_options|            payments|
# +--------------------+--------------------+--------------------+---------+----------+-----------+----------+--------------------+--------------------+--------------------+--------------------+
# |0x4cca3876b359eea...|Homestead Restaurant|Homestead Restaur...|44.705822| -73.51141|       null|      78.0|['Breakfast resta...|                null|        ["Delivery"]|                null|
# |0x4cca38bd56e9b69...|  Meron's Restaurant|Meron's Restauran...|44.704376| -73.46721|       null|      83.0|['Bar', 'American...|                null|["Takeout","Deliv...|                null|
# |0x4cca477e599e607...|Little Caesars Pizza|Little Caesars Pi...|44.701073| -73.49436|       null|      54.0|['Pizza restauran...|  ["Lunch","Dinner"]|["Curbside pickup...|     ["Debit cards"]|
# |0x4ccae300ee20ad6...|Sol de oro, Sport...|Sol de oro, Sport...|  44.2844| -73.98402|       null|      68.0|['Sports bar', 'P...|                null|["Outdoor seating...|["Debit cards","C...|
# |0x882d461181ded22...|    Tap Room & Grill|Tap Room & Grill,...|42.322987| -79.57696|       null|      58.0|      ['Restaurant']|                null|["Takeout","Deliv...|                null|
# |0x89c2454af51d61a...|      Seafood Island|Seafood Island, 7...|40.637657| -74.00811|       null|      35.0|['Sichuan restaur...|                null|["Takeout","Dine-...|                null|
# |0x89c258a3ceebfff...|            Vicolina|Vicolina, 1302 Ma...| 40.78501| -73.95607|       null|      48.0|['Italian restaur...|["Lunch","Dinner"...|["Outdoor seating...|["NFC mobile paym...|
# |0x89c258bbc2d1ac9...|               Charc|Charc, 316 E 84th...| 40.77603|-73.951996|       null|      28.0|['Bar tabac', 'Ba...|                null|        ["Delivery"]|     ["Debit cards"]|
# |0x89c258e2e187781...|            DeGrezia|DeGrezia, 231 E 5...|40.755493| -73.96944|       null|     114.0|['Italian restaur...|         ["Dessert"]|         ["Takeout"]|                null|
# |0x89c2594464f46e5...|Izzies Cheesestea...|Izzies Cheesestea...|40.719788| -73.98486|       null|      98.0|['Cheesesteak res...|["Lunch","Dinner"...|["Curbside pickup...|["Debit cards","N...|
# |0x89c259669bd02f1...|Amelia Grilled Bu...|Amelia Grilled Bu...|40.714275| -73.94594|       null|      38.0|['Burrito restaur...|                null|["No-contact deli...|["NFC mobile paym...|
# |0x89c25987014a6fe...|        Milk & Honey|Milk & Honey, 134...|40.718906| -73.99145|       null|      28.0|['Restaurant', 'B...|                null|        ["Delivery"]|                null|
# |0x89c2599eeaad61a...|         Bruno Pizza|Bruno Pizza, 204 ...|40.732304| -73.98735|       null|     176.0|['Pizza restauran...|         ["Dessert"]|["Takeout","Deliv...|                null|
# |0x89c25a27a5c9884...|          Matsunichi|Matsunichi, 14-18...|40.715866|-73.997246|       null|      48.0|['Sushi restaurant']|                null|        ["Delivery"]|["NFC mobile paym...|
# |0x89c25a447540cdb...|       Bark Hot Dogs|Bark Hot Dogs, 47...|40.680767|-73.975655|       null|      75.0|['Hot dog restaur...|  ["Lunch","Dinner"]|        ["Delivery"]|                null|
# |0x89c25a4b90d6c8e...|Fresh 99 cents pizza|Fresh 99 cents pi...| 40.69231|-73.986855|       null|     138.0|['Pizza restaurant']|                null|         ["Takeout"]|                null|
# |0x89c25ab347c903d...|    El Sol Migueleno|El Sol Migueleno,...|40.641544| -74.01381|       null|      47.0|['Salvadoran rest...|                null|        ["Delivery"]|                null|
# |0x89c25b4da7eeffa...|      Yoyo Fritaille|Yoyo Fritaille, 2...| 40.63442|-73.949974|       null|      38.0|['Haitian restaur...|                null|["Delivery","Take...|       ["Cash-only"]|
# |0x89c25c072921e59...|                Koda|Koda, 985 Flushin...| 40.70311| -73.93332|       null|     118.0|['New American re...|                null|["Takeout","Dine-...|                null|
# |0x89c25c26b1e1c15...|            San Remo|San Remo, 56-01 M...|40.700306| -73.90614|       null|     147.0|['Pizza restauran...|["Lunch","Dinner"...|["No-contact deli...|     ["Debit cards"]|
# +--------------------+--------------------+--------------------+---------+----------+-----------+----------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
import pandas as pd

parquet = pd.read_parquet('/home/ezequiell/Descargas/part-00000-0991daf0-ef5c-4869-8d8d-2074d75673e5-c000.snappy.parquet')

        
parquet
# Out:
#                                      gmap_id  \
# 0      0x405bccf4faffeddb:0x62d94b9cf01c7343
# 1      0x4065fceb0cc40965:0xb22a3c3f2333007f
# 2      0x4065fd2182da474b:0x4ce97af5b7bc6aaa
# 3      0x4065fd21ad7ef4b9:0x85921e7c5ca9a854
# 4      0x4cb55591479ba9b1:0xb7414620dd33a3c8
# ...                                      ...
# 59507  0x89ef53545fe220fd:0xfb291378fd84cb23
# 59508  0x89ef53566c137d75:0xae02dd8a1886d1ae
# 59509  0x89ef53567024873f:0xa1bcae42b612aa21
# 59510  0x89ef54a82b96b90d:0xd3a4f7249d42450d
# 59511  0x89ef55ecab47d7a7:0x5c93c868596cf0ef
#
#                                                     name  \
# 0                                             Mellow Mug
# 1                                                    GNC
# 2                                        Hale and Hearty
# 3      ManhattanTechSupport.com LLC - IT Support & Se...
# 4                           Tonys Ticonderoga Sports Inc
# ...                                                  ...
# 59507                      Puff & Putt Family Fun Center
# 59508                                           M&R DELI
# 59509                              Montauk Surf & Sports
# 59510                                      Herb's Market
# 59511                               Naturally Good Sushi
#
#                                                  address   latitude  \
# 0      Mellow Mug, 616 Pittsford Victor Rd, Pittsford...  43.062222
# 1                   GNC, 549 6th Ave, New York, NY 10011  40.738014
# 2      Hale and Hearty, 369 Lexington Ave, New York, ...  40.750408
# 3      ManhattanTechSupport.com LLC - IT Support & Se...  40.752842
# 4      Tonys Ticonderoga Sports Inc, 1186 NY-9N, Tico...  43.860607
# ...                                                  ...        ...
# 59507  Puff & Putt Family Fun Center, 659 Montauk Hwy...  41.032173
# 59508       M&R DELI, 728 Montauk Hwy, Montauk, NY 11954  41.033882
# 59509  Montauk Surf & Sports, 716 Main Street, Montau...  41.033737
# 59510  Herb's Market, 778 Montauk Hwy, Montauk, NY 11954  41.035301
# 59511  Naturally Good Sushi, 38 S Etna Ave, Montauk, ...  41.035137
#
#        longitude  num_reviews  avg_rating  \
# 0     -77.479034           88         4.4
# 1     -73.996620           28         3.7
# 2     -73.976479           25         4.2
# 3     -73.984795          115         4.9
# 4     -73.437401           77         4.2
# ...          ...          ...         ...
# 59507 -71.948837           68         4.5
# 59508 -71.945023           65         4.5
# 59509 -71.945236           38         3.9
# 59510 -71.942902           24         4.2
# 59511 -71.941040           27         4.8
#
#                                                 category  \
# 0      ['Coffee shop', 'Bar', 'Bistro', 'Cafe', 'Wine...
# 1      ['Vitamin & supplements store', 'Health food s...
# 2      ['Soup shop', 'Caterer', 'Delivery Restaurant'...
# 3      ['Computer support and services', 'Business to...
# 4      ['Car inspection station', 'ATV dealer', 'Auto...
# ...                                                  ...
# 59507  ['Miniature golf course', 'Boat rental service...
# 59508                                           ['Deli']
# 59509                           ['Sporting goods store']
# 59510                                   ['Butcher shop']
# 59511                                 ['Sushi takeaway']
#
#               dining_options  \
# 0                       None
# 1                       None
# 2      ["Dessert","Seating"]
# 3                       None
# 4                       None
# ...                      ...
# 59507                   None
# 59508                   None
# 59509                   None
# 59510                   None
# 59511                   None
#
#                                          service_options  \
# 0                                 ["Takeout","Delivery"]
# 1                ["In-store pickup","In-store shopping"]
# 2           ["No-contact delivery","Delivery","Takeout"]
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 59507                                               None
# 59508  ["Delivery","In-store pickup","In-store shoppi...
# 59509  ["Curbside pickup","In-store pickup","In-store...
# 59510            ["In-store pickup","In-store shopping"]
# 59511  ["Curbside pickup","Takeout","Dine-in","Delive...
#
#                                                 payments
# 0                                                   None
# 1         ["Checks","Debit cards","NFC mobile payments"]
# 2      ["Debit cards","NFC mobile payments","Credit c...
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 59507                                               None
# 59508                                               None
# 59509                                               None
# 59510                            ["NFC mobile payments"]
# 59511                                               None
#
# [59512 rows x 11 columns]
