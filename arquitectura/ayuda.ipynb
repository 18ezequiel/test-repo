# %%
import sys
from pyspark.context import SparkContext
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.sql import SparkSession
import datetime
from pyspark.sql.functions import expr
from pyspark.sql.functions import col, array_contains
from pyspark.sql.functions import lower


# Definimos el mapping que aplicará la transformación a la columna 'time'
schema = StructType([
            StructField("name", StringType(), True),
            StructField("address", StringType(), True),
            StructField("gmap_id", StringType(), True),
            StructField("description", StringType(), True),
            StructField("latitude", FloatType(), True),
            StructField("longitude", FloatType(), True),
            StructField("category", StringType(), True),
            StructField("avg_rating", FloatType(), True),
            StructField("num_of_reviews", IntegerType(), True),
            StructField("price", FloatType(), True),
            StructField("hours", StringType(), True),
            StructField("MISC", StringType(), True)
            ])


spark = SparkSession.builder.appName("MiApp").getOrCreate()

df = spark.read.csv("/home/ezequiell/Descargas/metada_newyork.csv", header=True, schema=schema)
df.printSchema()
df.show()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- address: string (nullable = true)
#  |-- gmap_id: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- latitude: float (nullable = true)
#  |-- longitude: float (nullable = true)
#  |-- category: string (nullable = true)
#  |-- avg_rating: float (nullable = true)
#  |-- num_of_reviews: integer (nullable = true)
#  |-- price: float (nullable = true)
#  |-- hours: string (nullable = true)
#  |-- MISC: string (nullable = true)
#
# 23/02/22 15:22:29 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 15, schema size: 12
# CSV file: file:///home/ezequiell/Descargas/metada_newyork.csv
# +--------------------+--------------------+--------------------+--------------------+---------+----------+--------------------+----------+--------------+-----+--------------------+--------------------+
# |                name|             address|             gmap_id|         description| latitude| longitude|            category|avg_rating|num_of_reviews|price|               hours|                MISC|
# +--------------------+--------------------+--------------------+--------------------+---------+----------+--------------------+----------+--------------+-----+--------------------+--------------------+
# |Shelter Cove Apar...|Shelter Cove Apar...|0x405b94b45e01bc0...|                null|42.806812|  -73.7395|['Apartment renta...|       4.2|            36| null|[['Saturday', '10...|{'Health & safety...|
# |       Mcneillys Pub|Mcneillys Pub, 30...|0x405bccedd9871fd...|                null|43.058044| -76.12334|             ['Pub']|       4.3|            76| null|[['Monday', '10AM...|{'Service options...|
# |          Mellow Mug|Mellow Mug, 616 P...|0x405bccf4faffedd...|                null| 43.06222|-77.479034|['Coffee shop', '...|       4.4|            88| null|[['Wednesday', '7...|{'Service options...|
# |New Holland Resid...|New Holland Resid...|0x4066087f183b65c...|                null|40.804264| -73.95458|['Corporate office']|       1.8|            53| null|[['Friday', '9AM–...|                null|
# |             Lincare|Lincare, 1437 NY-...|0x406790f7e0a67f8...|                null|41.484787| -74.07281|['Oxygen equipmen...|       1.8|            47| null|[['Thursday', '8A...|                null|
# |North Country Gol...|North Country Gol...|0x4cc987f789377c6...|                null| 44.98968| -73.39465|     ['Golf course']|       4.5|            47| null|[['Friday', '7:30...|{'Accessibility':...|
# |             Dunkin'|Dunkin', 1038 Sta...|0x4cca29c04f91cd3...|Long-running chai...| 44.98149|-73.459274|['Coffee shop', '...|       3.5|           135| null|[['Monday', '5AM–...|{'Service options...|
# |       CODYS GROCERY|CODYS GROCERY, 29...|0x4cca36d5b2fee80...|                null| 44.78085|-73.556755|     ['Gas station']|       4.1|            16| null|                null|                null|
# |Pawfection Pet Gr...|Pawfection Pet Gr...|0x4cca380999e7461...|                null| 44.70508|-73.527214|     ['Pet groomer']|       4.9|            28| null|                null|{'Accessibility':...|
# |Homestead Restaurant|Homestead Restaur...|0x4cca3876b359eea...|                null|44.705822| -73.51141|['Breakfast resta...|       3.8|            78| null|[['Tuesday', '6AM...|{'Service options...|
# |     Body Art Tattoo|Body Art Tattoo, ...|0x4cca38a95dded20...|                null| 44.69608|-73.453094|['Tattoo shop', '...|       4.8|            98| null|[['Tuesday', '11A...|{'Service options...|
# |The Corner Stone ...|The Corner Stone ...|0x4cca38ae9559973...|                null|44.698368| -73.45281| ['Used book store']|       4.7|            68| null|[['Monday', 'Clos...|{'Service options...|
# |  Meron's Restaurant|Meron's Restauran...|0x4cca38bd56e9b69...|                null|44.704376| -73.46721|['Bar', 'American...|       4.5|            83| null|[['Friday', '3PM–...|{'Service options...|
# |StoneWorks Massag...|StoneWorks Massag...|0x4cca38c819478d0...|                null|44.727478|  -73.4345|['Massage therapi...|       4.9|            44| null|[['Sunday', '8:45...|{'Health & safety...|
# |   RR Charlebois Inc|RR Charlebois Inc...|0x4cca38ecaf94c21...|                null|44.714264| -73.46887|    ['Truck dealer']|       4.7|            27| null|[['Monday', '7:30...|{'Service options...|
# |Ausable Marsh Wil...|Ausable Marsh Wil...|0x4cca428e3258bf2...|Conservation wetl...|44.568447| -73.43351|['Park', 'Tourist...|       4.5|            68| null|                null|                null|
# |     New Impressions|New Impressions, ...|0x4cca449aa1295e4...|                null| 44.57926| -73.52843|['Beauty salon', ...|       4.8|            28| null|[['Saturday', '9A...|{'Health & safety...|
# |Champlain Valley ...|Champlain Valley ...|0x4cca4762a84f4f3...|                null|44.696167| -73.49234|['Veterinarian', ...|       4.5|            76| null|[['Saturday', '8A...|{'Accessibility':...|
# |Little Caesars Pizza|Little Caesars Pi...|0x4cca477e599e607...|                null|44.701073| -73.49436|['Pizza restauran...|       3.3|            54| null|[['Saturday', '12...|{'Service options...|
# |           CosmoProf|CosmoProf, 494 NY...|0x4cca477fa3752e2...|                null|44.696938| -73.49623|['Beauty supply s...|       4.4|            15| null|[['Tuesday', '8AM...|{'Service options...|
# +--------------------+--------------------+--------------------+--------------------+---------+----------+--------------------+----------+--------------+-----+--------------------+--------------------+
# only showing top 20 rows

# %%
# filtramos solo el rubro de restaurantes que es en lo que se enfocara el sistema de recomendacion
df = df.filter(lower(df["category"]).like("%restaurant%"))


df2 = df.select("*", from_json("MISC", "map<string,string>").alias("mapa_misc"))

# Usar explode para crear una fila por cada clave del diccionario
df3 = df2.select("*", explode("mapa_misc").alias("clave", "valor"))

df3 = df3.withColumn("clave", regexp_replace("clave", " ", "_"))

# Usar pivot para convertir las claves en columnas
df4 = df3.groupBy("gmap_id").pivot("clave").agg({"valor": "first"})

#df4.printSchema()

# Unir el resultado de pivot con las columnas originales
df_final = df3.join(df4, on="gmap_id")

#df_final.printSchema()

df = df_final.select('gmap_id', 'name', 'address', 'latitude', 'longitude', 'num_of_reviews', 'avg_rating', 'category', 'Dining_options', 'Service_options', 'Payments')

df = df \
    .select(col("gmap_id").alias("gmap_id"), \
            col("name").alias("name"), \
            col("address").alias("address"), \
            col("latitude").alias("latitude"), \
            col("longitude").alias("longitude"), \
            col("num_of_reviews").alias("num_reviews"), \
            col("avg_rating").alias("avg_rating"), \
            col("category").alias("category"), \
            col("Dining_options").alias("dining_options"), \
            col("Service_options").alias("service_options"), \
            col("Payments").alias("payments")) \
    .dropDuplicates()

df.printSchema()
df.show()
# Out:
# root
#  |-- gmap_id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- address: string (nullable = true)
#  |-- latitude: float (nullable = true)
#  |-- longitude: float (nullable = true)
#  |-- num_reviews: integer (nullable = true)
#  |-- avg_rating: float (nullable = true)
#  |-- category: string (nullable = true)
#  |-- dining_options: string (nullable = true)
#  |-- service_options: string (nullable = true)
#  |-- payments: string (nullable = true)
#
# 23/02/21 16:46:59 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: name, address, gmap_id, latitude, longitude, category, avg_rating, num_of_reviews, MISC
#  Schema: name, address, gmap_id, latitude, longitude, category, num_of_reviews, avg_rating, MISC
# Expected: num_of_reviews but found: avg_rating
# CSV file: file:///home/ezequiell/Descargas/metada_newyork.csv
# +--------------------+--------------------+--------------------+---------+----------+-----------+----------+--------------------+--------------------+--------------------+--------------------+
# |             gmap_id|                name|             address| latitude| longitude|num_reviews|avg_rating|            category|      dining_options|     service_options|            payments|
# +--------------------+--------------------+--------------------+---------+----------+-----------+----------+--------------------+--------------------+--------------------+--------------------+
# |0x4cca3876b359eea...|Homestead Restaurant|Homestead Restaur...|44.705822| -73.51141|       null|      78.0|['Breakfast resta...|                null|        ["Delivery"]|                null|
# |0x4cca38bd56e9b69...|  Meron's Restaurant|Meron's Restauran...|44.704376| -73.46721|       null|      83.0|['Bar', 'American...|                null|["Takeout","Deliv...|                null|
# |0x4cca477e599e607...|Little Caesars Pizza|Little Caesars Pi...|44.701073| -73.49436|       null|      54.0|['Pizza restauran...|  ["Lunch","Dinner"]|["Curbside pickup...|     ["Debit cards"]|
# |0x4ccae300ee20ad6...|Sol de oro, Sport...|Sol de oro, Sport...|  44.2844| -73.98402|       null|      68.0|['Sports bar', 'P...|                null|["Outdoor seating...|["Debit cards","C...|
# |0x882d461181ded22...|    Tap Room & Grill|Tap Room & Grill,...|42.322987| -79.57696|       null|      58.0|      ['Restaurant']|                null|["Takeout","Deliv...|                null|
# |0x89c2454af51d61a...|      Seafood Island|Seafood Island, 7...|40.637657| -74.00811|       null|      35.0|['Sichuan restaur...|                null|["Takeout","Dine-...|                null|
# |0x89c258a3ceebfff...|            Vicolina|Vicolina, 1302 Ma...| 40.78501| -73.95607|       null|      48.0|['Italian restaur...|["Lunch","Dinner"...|["Outdoor seating...|["NFC mobile paym...|
# |0x89c258bbc2d1ac9...|               Charc|Charc, 316 E 84th...| 40.77603|-73.951996|       null|      28.0|['Bar tabac', 'Ba...|                null|        ["Delivery"]|     ["Debit cards"]|
# |0x89c258e2e187781...|            DeGrezia|DeGrezia, 231 E 5...|40.755493| -73.96944|       null|     114.0|['Italian restaur...|         ["Dessert"]|         ["Takeout"]|                null|
# |0x89c2594464f46e5...|Izzies Cheesestea...|Izzies Cheesestea...|40.719788| -73.98486|       null|      98.0|['Cheesesteak res...|["Lunch","Dinner"...|["Curbside pickup...|["Debit cards","N...|
# |0x89c259669bd02f1...|Amelia Grilled Bu...|Amelia Grilled Bu...|40.714275| -73.94594|       null|      38.0|['Burrito restaur...|                null|["No-contact deli...|["NFC mobile paym...|
# |0x89c25987014a6fe...|        Milk & Honey|Milk & Honey, 134...|40.718906| -73.99145|       null|      28.0|['Restaurant', 'B...|                null|        ["Delivery"]|                null|
# |0x89c2599eeaad61a...|         Bruno Pizza|Bruno Pizza, 204 ...|40.732304| -73.98735|       null|     176.0|['Pizza restauran...|         ["Dessert"]|["Takeout","Deliv...|                null|
# |0x89c25a27a5c9884...|          Matsunichi|Matsunichi, 14-18...|40.715866|-73.997246|       null|      48.0|['Sushi restaurant']|                null|        ["Delivery"]|["NFC mobile paym...|
# |0x89c25a447540cdb...|       Bark Hot Dogs|Bark Hot Dogs, 47...|40.680767|-73.975655|       null|      75.0|['Hot dog restaur...|  ["Lunch","Dinner"]|        ["Delivery"]|                null|
# |0x89c25a4b90d6c8e...|Fresh 99 cents pizza|Fresh 99 cents pi...| 40.69231|-73.986855|       null|     138.0|['Pizza restaurant']|                null|         ["Takeout"]|                null|
# |0x89c25ab347c903d...|    El Sol Migueleno|El Sol Migueleno,...|40.641544| -74.01381|       null|      47.0|['Salvadoran rest...|                null|        ["Delivery"]|                null|
# |0x89c25b4da7eeffa...|      Yoyo Fritaille|Yoyo Fritaille, 2...| 40.63442|-73.949974|       null|      38.0|['Haitian restaur...|                null|["Delivery","Take...|       ["Cash-only"]|
# |0x89c25c072921e59...|                Koda|Koda, 985 Flushin...| 40.70311| -73.93332|       null|     118.0|['New American re...|                null|["Takeout","Dine-...|                null|
# |0x89c25c26b1e1c15...|            San Remo|San Remo, 56-01 M...|40.700306| -73.90614|       null|     147.0|['Pizza restauran...|["Lunch","Dinner"...|["No-contact deli...|     ["Debit cards"]|
# +--------------------+--------------------+--------------------+---------+----------+-----------+----------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
import pandas as pd

parquet = pd.read_json('/home/ezequiell/Escritorio/arquitectura/salida_api_1.json')
        
df = parquet

# Divide la columna "coordenada" en dos columnas
df[['latitud', 'longitud']] = df['coordenada'].str.split(',', expand=True)

# Convierte las columnas "latitud" y "longitud" a tipo numérico
df['latitude'] = pd.to_numeric(df['latitud'])
df['longitude'] = pd.to_numeric(df['longitud'])

df = df[['gmap_id','name', 'address','longitude', 'latitude', 'avg_rating', 'category', 'delivery', 'takeout', 'serves_breakfast', 'serves_lunch', 'serves_dinner']]

df.to_parquet('metadata_002.parquet')

# %%
import sys
from pyspark.context import SparkContext
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.sql import SparkSession
import datetime
from pyspark.sql.functions import expr
from pyspark.sql.functions import col, array_contains
from pyspark.sql.functions import lower


# Definimos el mapping que aplicará la transformación a la columna 'time'
schema = StructType([
            StructField("name", StringType(), True),
            StructField("address", StringType(), True),
            StructField("gmap_id", StringType(), True),
            StructField("description", StringType(), True),
            StructField("latitude", FloatType(), True),
            StructField("longitude", FloatType(), True),
            StructField("category", StringType(), True),
            StructField("avg_rating", FloatType(), True),
            StructField("num_of_reviews", IntegerType(), True),
            StructField("price", FloatType(), True),
            StructField("hours", StringType(), True),
            StructField("MISC", StringType(), True)
            ])


spark = SparkSession.builder.appName("MiApp").getOrCreate()

df = spark.read.csv("/home/ezequiell/Descargas/metada_newyork.csv", header=True, schema=schema)
df.printSchema()
df.show()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- address: string (nullable = true)
#  |-- gmap_id: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- latitude: float (nullable = true)
#  |-- longitude: float (nullable = true)
#  |-- category: string (nullable = true)
#  |-- avg_rating: float (nullable = true)
#  |-- num_of_reviews: integer (nullable = true)
#  |-- price: float (nullable = true)
#  |-- hours: string (nullable = true)
#  |-- MISC: string (nullable = true)
#
# 23/02/22 16:02:37 WARN CSVHeaderChecker: Number of column in CSV header is not equal to number of fields in the schema:
#  Header length: 15, schema size: 12
# CSV file: file:///home/ezequiell/Descargas/metada_newyork.csv
# +--------------------+--------------------+--------------------+--------------------+---------+----------+--------------------+----------+--------------+-----+--------------------+--------------------+
# |                name|             address|             gmap_id|         description| latitude| longitude|            category|avg_rating|num_of_reviews|price|               hours|                MISC|
# +--------------------+--------------------+--------------------+--------------------+---------+----------+--------------------+----------+--------------+-----+--------------------+--------------------+
# |Shelter Cove Apar...|Shelter Cove Apar...|0x405b94b45e01bc0...|                null|42.806812|  -73.7395|['Apartment renta...|       4.2|            36| null|[['Saturday', '10...|{'Health & safety...|
# |       Mcneillys Pub|Mcneillys Pub, 30...|0x405bccedd9871fd...|                null|43.058044| -76.12334|             ['Pub']|       4.3|            76| null|[['Monday', '10AM...|{'Service options...|
# |          Mellow Mug|Mellow Mug, 616 P...|0x405bccf4faffedd...|                null| 43.06222|-77.479034|['Coffee shop', '...|       4.4|            88| null|[['Wednesday', '7...|{'Service options...|
# |New Holland Resid...|New Holland Resid...|0x4066087f183b65c...|                null|40.804264| -73.95458|['Corporate office']|       1.8|            53| null|[['Friday', '9AM–...|                null|
# |             Lincare|Lincare, 1437 NY-...|0x406790f7e0a67f8...|                null|41.484787| -74.07281|['Oxygen equipmen...|       1.8|            47| null|[['Thursday', '8A...|                null|
# |North Country Gol...|North Country Gol...|0x4cc987f789377c6...|                null| 44.98968| -73.39465|     ['Golf course']|       4.5|            47| null|[['Friday', '7:30...|{'Accessibility':...|
# |             Dunkin'|Dunkin', 1038 Sta...|0x4cca29c04f91cd3...|Long-running chai...| 44.98149|-73.459274|['Coffee shop', '...|       3.5|           135| null|[['Monday', '5AM–...|{'Service options...|
# |       CODYS GROCERY|CODYS GROCERY, 29...|0x4cca36d5b2fee80...|                null| 44.78085|-73.556755|     ['Gas station']|       4.1|            16| null|                null|                null|
# |Pawfection Pet Gr...|Pawfection Pet Gr...|0x4cca380999e7461...|                null| 44.70508|-73.527214|     ['Pet groomer']|       4.9|            28| null|                null|{'Accessibility':...|
# |Homestead Restaurant|Homestead Restaur...|0x4cca3876b359eea...|                null|44.705822| -73.51141|['Breakfast resta...|       3.8|            78| null|[['Tuesday', '6AM...|{'Service options...|
# |     Body Art Tattoo|Body Art Tattoo, ...|0x4cca38a95dded20...|                null| 44.69608|-73.453094|['Tattoo shop', '...|       4.8|            98| null|[['Tuesday', '11A...|{'Service options...|
# |The Corner Stone ...|The Corner Stone ...|0x4cca38ae9559973...|                null|44.698368| -73.45281| ['Used book store']|       4.7|            68| null|[['Monday', 'Clos...|{'Service options...|
# |  Meron's Restaurant|Meron's Restauran...|0x4cca38bd56e9b69...|                null|44.704376| -73.46721|['Bar', 'American...|       4.5|            83| null|[['Friday', '3PM–...|{'Service options...|
# |StoneWorks Massag...|StoneWorks Massag...|0x4cca38c819478d0...|                null|44.727478|  -73.4345|['Massage therapi...|       4.9|            44| null|[['Sunday', '8:45...|{'Health & safety...|
# |   RR Charlebois Inc|RR Charlebois Inc...|0x4cca38ecaf94c21...|                null|44.714264| -73.46887|    ['Truck dealer']|       4.7|            27| null|[['Monday', '7:30...|{'Service options...|
# |Ausable Marsh Wil...|Ausable Marsh Wil...|0x4cca428e3258bf2...|Conservation wetl...|44.568447| -73.43351|['Park', 'Tourist...|       4.5|            68| null|                null|                null|
# |     New Impressions|New Impressions, ...|0x4cca449aa1295e4...|                null| 44.57926| -73.52843|['Beauty salon', ...|       4.8|            28| null|[['Saturday', '9A...|{'Health & safety...|
# |Champlain Valley ...|Champlain Valley ...|0x4cca4762a84f4f3...|                null|44.696167| -73.49234|['Veterinarian', ...|       4.5|            76| null|[['Saturday', '8A...|{'Accessibility':...|
# |Little Caesars Pizza|Little Caesars Pi...|0x4cca477e599e607...|                null|44.701073| -73.49436|['Pizza restauran...|       3.3|            54| null|[['Saturday', '12...|{'Service options...|
# |           CosmoProf|CosmoProf, 494 NY...|0x4cca477fa3752e2...|                null|44.696938| -73.49623|['Beauty supply s...|       4.4|            15| null|[['Tuesday', '8AM...|{'Service options...|
# +--------------------+--------------------+--------------------+--------------------+---------+----------+--------------------+----------+--------------+-----+--------------------+--------------------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import lower
# filtramos solo el rubro de restaurantes que es en lo que se enfocara el sistema de recomendacion
#df.printSchema()
#df.distinct().show()

df2 = df.select("*", from_json("MISC", "map<string,string>").alias("mapa_misc"))

# Usar explode para crear una fila por cada clave del diccionario
df3 = df2.select("*", explode("mapa_misc").alias("clave", "valor"))

df3 = df3.withColumn("clave", regexp_replace("clave", " ", "_"))

# Usar pivot para convertir las claves en columnas
df4 = df3.groupBy("gmap_id").pivot("clave").agg({"valor": "first"})
#df4.printSchema()
#df4.show()

# Unir el resultado de pivot con las columnas originales
df_final = df3.join(df4, on="gmap_id")

#df_final.printSchema()
#df_final.show()

df = df_final.select('gmap_id', 'name', 'address', 'latitude', 'longitude', 'num_of_reviews', 'avg_rating', 'category', 'Dining_options', 'Service_options')

df = df \
    .select(col("gmap_id").alias("gmap_id"), \
            col("name").alias("name"), \
            col("address").alias("address"), \
            col("latitude").alias("latitude"), \
            col("longitude").alias("longitude"), \
            col("num_of_reviews").alias("num_reviews"), \
            col("avg_rating").alias("avg_rating"), \
            col("category").alias("category"), \
            col("Service_options").alias("service_options"), \
            col("Dining_options").alias("dining_options")) \
    .dropDuplicates()

df = df \
    .withColumn("delivery", when(lower(col("service_options")).contains("delivery"), "yes").otherwise("no")) \
    .withColumn("takeout", when(lower(col("service_options")).contains("takeout"), "yes").otherwise("no"))  \
    .withColumn("serves_breakfast", when(lower(col("dining_options")).contains("breakfast"), "yes").otherwise("no")) \
    .withColumn("serves_lunch", when(lower(col("dining_options")).contains("lunch"), "yes").otherwise("no")) \
    .withColumn("serves_dinner", when(lower(col("dining_options")).contains("dinner"), "yes").otherwise("no"))

df = df.drop("service_options")
df = df.drop("dining_options")

#df.printSchema()
#df.show()

df_test = df \
        .select(col("gmap_id"),\
                col("delivery"),\
                col("takeout"),\
                col("serves_breakfast"),\
                col("serves_lunch"),\
                col("serves_dinner"))

df_test.show()
# Out:
# +--------------------+--------+-------+----------------+------------+-------------+
# |             gmap_id|delivery|takeout|serves_breakfast|serves_lunch|serves_dinner|
# +--------------------+--------+-------+----------------+------------+-------------+
# |0x4cca3876b359eea...|     yes|     no|              no|          no|           no|
# |0x4cca38bd56e9b69...|     yes|    yes|              no|          no|           no|
# |0x4cca38ecaf94c21...|      no|     no|              no|          no|           no|
# |0x4cca477e599e607...|     yes|    yes|              no|         yes|          yes|
# |0x4cca9a763ec7307...|     yes|     no|              no|          no|           no|
# |0x4ccae300ee20ad6...|     yes|    yes|              no|          no|           no|
# |0x4ccc3fcef1249f7...|     yes|     no|              no|          no|           no|
# |0x4ccd19eb8ad4015...|      no|     no|              no|          no|           no|
# |0x882d461181ded22...|     yes|    yes|              no|          no|           no|
# |0x89c244642640f34...|      no|     no|              no|          no|           no|
# |0x89c24483a754f59...|      no|     no|              no|          no|           no|
# |0x89c244d639797b3...|      no|     no|              no|          no|           no|
# |0x89c244edd86fefc...|     yes|     no|              no|          no|           no|
# |0x89c244f4eae9262...|     yes|     no|              no|          no|           no|
# |0x89c24523d403fca...|      no|     no|              no|          no|           no|
# |0x89c2454af51d61a...|     yes|    yes|              no|          no|           no|
# |0x89c2454f6cb6c93...|      no|     no|              no|          no|           no|
# |0x89c2455c05e0996...|      no|    yes|              no|          no|           no|
# |0x89c2455db7f8abd...|     yes|     no|              no|          no|           no|
# |0x89c24a4aa7d14e7...|     yes|     no|              no|          no|           no|
# +--------------------+--------+-------+----------------+------------+-------------+
# only showing top 20 rows

# %%
import pandas as pd
import json

# Lee el archivo JSON y convierte la lista de lugares en un DataFrame de Pandas
with open('data.json', 'r') as f:
    data = json.load(f)
df = pd.DataFrame(data['places'])

# Imprime el DataFrame resultante
df
# Out:
#                                                  name  \
# 0                                  Wyckoff Restaurant
# 1                                          Grillwaale
# 2                                             Veranda
# 3                                    Magna Restaurant
# 4                           Remy's Italian Restaurant
# 5                       Papazzio Restaurant & Caterer
# 6                              la estrella restaurant
# 7                                   Ghoroa Restaurant
# 8                                               Molos
# 9   Junction Seafood Restaurant / Fast & Fresh Com...
# 10                                 ACherry Restaurant
# 11                           Cafe Colonial Restaurant
# 12                                          Balthazar
# 13                                   L.I. Valle Grill
# 14                                 Melba's Restaurant
# 15                               Charlie's Restaurant
# 16                                       Restaurant X
# 17              Honey Badger | Fine Dining Restaurant
# 18                       Manna's Soul Food Restaurant
# 19                      Antonino's Italian Restaurant
#
#                                        coordinates  \
# 0     {'lat': 40.70038, 'lng': -73.91312099999999}
# 1           {'lat': 40.721888, 'lng': -73.6069934}
# 2   {'lat': 40.7590444, 'lng': -73.77538609999999}
# 3            {'lat': 40.763661, 'lng': -73.831291}
# 4          {'lat': 40.6369934, 'lng': -73.7031326}
# 5          {'lat': 40.7642933, 'lng': -73.7715288}
# 6   {'lat': 40.8514649, 'lng': -73.89903249999999}
# 7   {'lat': 40.7107225, 'lng': -73.79343639999999}
# 8   {'lat': 40.7712931, 'lng': -74.01331909999999}
# 9          {'lat': 40.7534246, 'lng': -73.8720155}
# 10         {'lat': 40.5976715, 'lng': -73.9608073}
# 11         {'lat': 40.8526076, 'lng': -73.8673579}
# 12   {'lat': 40.722668, 'lng': -73.99822979999999}
# 13  {'lat': 40.7087068, 'lng': -73.68478999999999}
# 14    {'lat': 40.80311, 'lng': -73.95662949999999}
# 15         {'lat': 40.7882343, 'lng': -74.0164589}
# 16         {'lat': 40.8306362, 'lng': -73.6934393}
# 17         {'lat': 40.6582071, 'lng': -73.9599683}
# 18         {'lat': 40.8133483, 'lng': -73.9410958}
# 19         {'lat': 40.7872605, 'lng': -73.7061559}
#
#                                            categories  \
# 0   [restaurant, meal_takeaway, food, point_of_int...
# 1   [restaurant, food, point_of_interest, establis...
# 2   [restaurant, food, point_of_interest, establis...
# 3   [restaurant, food, point_of_interest, establis...
# 4   [meal_takeaway, bar, restaurant, food, point_o...
# 5   [bar, restaurant, food, point_of_interest, est...
# 6   [restaurant, food, point_of_interest, establis...
# 7   [restaurant, food, point_of_interest, establis...
# 8   [restaurant, food, point_of_interest, establis...
# 9   [restaurant, food, point_of_interest, establis...
# 10  [restaurant, food, point_of_interest, establis...
# 11  [meal_delivery, restaurant, food, point_of_int...
# 12  [bakery, store, restaurant, food, point_of_int...
# 13  [restaurant, food, point_of_interest, establis...
# 14  [restaurant, food, point_of_interest, establis...
# 15  [restaurant, food, point_of_interest, establis...
# 16  [restaurant, food, point_of_interest, establis...
# 17  [restaurant, food, point_of_interest, establis...
# 18  [restaurant, food, point_of_interest, establis...
# 19  [meal_delivery, restaurant, food, point_of_int...
#
#                         gmap_id  \
# 0   ChIJqcy6-hRdwokRdSLrTxc6e8s
# 1   ChIJjdcjJ2B9wokRTBzKGKs9uLo
# 2   ChIJeQ7OPtxhwokR0NbauaysWDM
# 3   ChIJT5fPRAVgwokRApCD3ei8UFQ
# 4   ChIJWThxmr5lwokRm5Oy36a-7LI
# 5   ChIJd2gn_99hwokRjFzrReZ66uQ
# 6   ChIJs7wVgLn1wokRbaji3Nzt9N8
# 7   ChIJIZ4YNR5hwokR8GxzYqcfnZU
# 8   ChIJIQkdpDtYwokRtRIP3xnQs2Y
# 9   ChIJv8YfMdBfwokRGbXaIhS-wLo
# 10  ChIJxfTWgHhFwokRqp-mL6lnFeg
# 11  ChIJ_eSjOp_0wokRlY2ZkWUHo8c
# 12  ChIJt7fMLIlZwokRCRtM9bNDg78
# 13  ChIJG_4p0MRjwokR-J3YXt3npJU
# 14  ChIJ-bhM6yL2wokRAtIoWi_TL2k
# 15  ChIJibl2PxBYwokRCBkiv0UNnLk
# 16  ChIJ__84a9OIwokR849c3fxlTug
# 17  ChIJPwg6URNbwokR_YxBHdIupJ8
# 18  ChIJH97jp3b2wokRyoBwNMM-F9U
# 19  ChIJNWbGKqyJwokRPs-EPeJM5Cg
#
#                                                   url  total_ratings delivery  \
# 0   https://www.google.com/maps/place/?q=place_id:...             42       No
# 1   https://www.google.com/maps/place/?q=place_id:...             73       No
# 2   https://www.google.com/maps/place/?q=place_id:...            637       No
# 3   https://www.google.com/maps/place/?q=place_id:...            243       No
# 4   https://www.google.com/maps/place/?q=place_id:...            127       No
# 5   https://www.google.com/maps/place/?q=place_id:...            282       No
# 6   https://www.google.com/maps/place/?q=place_id:...             11       No
# 7   https://www.google.com/maps/place/?q=place_id:...            524       No
# 8   https://www.google.com/maps/place/?q=place_id:...           1894       No
# 9   https://www.google.com/maps/place/?q=place_id:...             55       No
# 10  https://www.google.com/maps/place/?q=place_id:...            265       No
# 11  https://www.google.com/maps/place/?q=place_id:...           1560       No
# 12  https://www.google.com/maps/place/?q=place_id:...           5933       No
# 13  https://www.google.com/maps/place/?q=place_id:...             49       No
# 14  https://www.google.com/maps/place/?q=place_id:...           3077       No
# 15  https://www.google.com/maps/place/?q=place_id:...            265       No
# 16  https://www.google.com/maps/place/?q=place_id:...             48       No
# 17  https://www.google.com/maps/place/?q=place_id:...            225       No
# 18  https://www.google.com/maps/place/?q=place_id:...            382       No
# 19  https://www.google.com/maps/place/?q=place_id:...            349       No
#
#    takeout
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No
# 5       No
# 6       No
# 7       No
# 8       No
# 9       No
# 10      No
# 11      No
# 12      No
# 13      No
# 14      No
# 15      No
# 16      No
# 17      No
# 18      No
# 19      No

# %%
import requests
import pandas as pd

# Configura la URL base para la API de Google Places
places_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# Configura los parámetros de la búsqueda
params = {
    "location": "40.69313,-73.57546", # coordenadas de Nueva York
    "radius": 38224, # radio de búsqueda en metros
    "type": "restaurant", # tipo de lugar a buscar
    "region" : "NY",
    "key": "AIzaSyB2v7bruAooTsZ1Xj_B022vn9I4F3SeDMQ", # clave de API de Google Maps
    "fields": "name,geometry,types,place_id,user_ratings_total,url",
    "keyword": "restaurant",
}

# Realiza la solicitud a la API de Places de Google Maps
response = requests.get(places_url, params=params)

# Procesa la respuesta de la API
if response.status_code == 200:
    # Si la respuesta es correcta, procesa la información
    results = response.json()["results"]
    #print(results)

    df = pd.DataFrame(results)

df
# Out:
#    business_status                                           geometry  \
# 0      OPERATIONAL  {'location': {'lat': 40.70038, 'lng': -73.9131...
# 1      OPERATIONAL  {'location': {'lat': 40.721888, 'lng': -73.606...
# 2      OPERATIONAL  {'location': {'lat': 40.7590444, 'lng': -73.77...
# 3      OPERATIONAL  {'location': {'lat': 40.763661, 'lng': -73.831...
# 4      OPERATIONAL  {'location': {'lat': 40.6369934, 'lng': -73.70...
# 5      OPERATIONAL  {'location': {'lat': 40.7642933, 'lng': -73.77...
# 6      OPERATIONAL  {'location': {'lat': 40.8514649, 'lng': -73.89...
# 7      OPERATIONAL  {'location': {'lat': 40.7107225, 'lng': -73.79...
# 8      OPERATIONAL  {'location': {'lat': 40.7712931, 'lng': -74.01...
# 9      OPERATIONAL  {'location': {'lat': 40.7534246, 'lng': -73.87...
# 10     OPERATIONAL  {'location': {'lat': 40.5976715, 'lng': -73.96...
# 11     OPERATIONAL  {'location': {'lat': 40.8526076, 'lng': -73.86...
# 12     OPERATIONAL  {'location': {'lat': 40.722668, 'lng': -73.998...
# 13     OPERATIONAL  {'location': {'lat': 40.7087068, 'lng': -73.68...
# 14     OPERATIONAL  {'location': {'lat': 40.80311, 'lng': -73.9566...
# 15     OPERATIONAL  {'location': {'lat': 40.7882343, 'lng': -74.01...
# 16     OPERATIONAL  {'location': {'lat': 40.8306362, 'lng': -73.69...
# 17     OPERATIONAL  {'location': {'lat': 40.6582071, 'lng': -73.95...
# 18     OPERATIONAL  {'location': {'lat': 40.8133483, 'lng': -73.94...
# 19     OPERATIONAL  {'location': {'lat': 40.7560837, 'lng': -73.99...
#
#                                                  icon icon_background_color  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 5   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 6   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 7   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 8   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 11  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 12  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 14  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 15  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 17  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 18  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
# 19  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
#
#                                    icon_mask_base_uri  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...
# 5   https://maps.gstatic.com/mapfiles/place_api/ic...
# 6   https://maps.gstatic.com/mapfiles/place_api/ic...
# 7   https://maps.gstatic.com/mapfiles/place_api/ic...
# 8   https://maps.gstatic.com/mapfiles/place_api/ic...
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...
# 11  https://maps.gstatic.com/mapfiles/place_api/ic...
# 12  https://maps.gstatic.com/mapfiles/place_api/ic...
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...
# 14  https://maps.gstatic.com/mapfiles/place_api/ic...
# 15  https://maps.gstatic.com/mapfiles/place_api/ic...
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...
# 17  https://maps.gstatic.com/mapfiles/place_api/ic...
# 18  https://maps.gstatic.com/mapfiles/place_api/ic...
# 19  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                                  name        opening_hours  \
# 0                                  Wyckoff Restaurant   {'open_now': True}
# 1                                          Grillwaale   {'open_now': True}
# 2                                             Veranda   {'open_now': True}
# 3                                    Magna Restaurant  {'open_now': False}
# 4                           Remy's Italian Restaurant   {'open_now': True}
# 5                       Papazzio Restaurant & Caterer   {'open_now': True}
# 6                              la estrella restaurant   {'open_now': True}
# 7                                   Ghoroa Restaurant   {'open_now': True}
# 8                                               Molos   {'open_now': True}
# 9   Junction Seafood Restaurant / Fast & Fresh Com...   {'open_now': True}
# 10                                 ACherry Restaurant   {'open_now': True}
# 11                           Cafe Colonial Restaurant   {'open_now': True}
# 12                                          Balthazar   {'open_now': True}
# 13                                   L.I. Valle Grill   {'open_now': True}
# 14                                 Melba's Restaurant   {'open_now': True}
# 15                               Charlie's Restaurant   {'open_now': True}
# 16                                       Restaurant X                  NaN
# 17              Honey Badger | Fine Dining Restaurant  {'open_now': False}
# 18                       Manna's Soul Food Restaurant   {'open_now': True}
# 19                                     The Restaurant   {'open_now': True}
#
#                                                photos  \
# 0   [{'height': 1536, 'html_attributions': ['<a hr...
# 1   [{'height': 4032, 'html_attributions': ['<a hr...
# 2   [{'height': 3024, 'html_attributions': ['<a hr...
# 3   [{'height': 1000, 'html_attributions': ['<a hr...
# 4   [{'height': 3024, 'html_attributions': ['<a hr...
# 5   [{'height': 4032, 'html_attributions': ['<a hr...
# 6   [{'height': 4032, 'html_attributions': ['<a hr...
# 7   [{'height': 4032, 'html_attributions': ['<a hr...
# 8   [{'height': 700, 'html_attributions': ['<a hre...
# 9   [{'height': 4032, 'html_attributions': ['<a hr...
# 10  [{'height': 4000, 'html_attributions': ['<a hr...
# 11  [{'height': 2992, 'html_attributions': ['<a hr...
# 12  [{'height': 4032, 'html_attributions': ['<a hr...
# 13  [{'height': 3024, 'html_attributions': ['<a hr...
# 14  [{'height': 3120, 'html_attributions': ['<a hr...
# 15  [{'height': 4032, 'html_attributions': ['<a hr...
# 16  [{'height': 3024, 'html_attributions': ['<a hr...
# 17  [{'height': 3024, 'html_attributions': ['<a hr...
# 18  [{'height': 1280, 'html_attributions': ['<a hr...
# 19  [{'height': 2403, 'html_attributions': ['<a hr...
#
#                        place_id  \
# 0   ChIJqcy6-hRdwokRdSLrTxc6e8s
# 1   ChIJjdcjJ2B9wokRTBzKGKs9uLo
# 2   ChIJeQ7OPtxhwokR0NbauaysWDM
# 3   ChIJT5fPRAVgwokRApCD3ei8UFQ
# 4   ChIJWThxmr5lwokRm5Oy36a-7LI
# 5   ChIJd2gn_99hwokRjFzrReZ66uQ
# 6   ChIJs7wVgLn1wokRbaji3Nzt9N8
# 7   ChIJIZ4YNR5hwokR8GxzYqcfnZU
# 8   ChIJIQkdpDtYwokRtRIP3xnQs2Y
# 9   ChIJv8YfMdBfwokRGbXaIhS-wLo
# 10  ChIJxfTWgHhFwokRqp-mL6lnFeg
# 11  ChIJ_eSjOp_0wokRlY2ZkWUHo8c
# 12  ChIJt7fMLIlZwokRCRtM9bNDg78
# 13  ChIJG_4p0MRjwokR-J3YXt3npJU
# 14  ChIJ-bhM6yL2wokRAtIoWi_TL2k
# 15  ChIJibl2PxBYwokRCBkiv0UNnLk
# 16  ChIJ__84a9OIwokR849c3fxlTug
# 17  ChIJPwg6URNbwokR_YxBHdIupJ8
# 18  ChIJH97jp3b2wokRyoBwNMM-F9U
# 19  ChIJXSm3bU9ZwokRKRX6nypuFlQ
#
#                                             plus_code  price_level  rating  \
# 0   {'compound_code': 'P32P+5Q Brooklyn, New York'...          1.0     3.5
# 1   {'compound_code': 'P9CV+Q6 Uniondale, New York...          NaN     4.5
# 2   {'compound_code': 'Q65F+JR New York', 'global_...          2.0     4.3
# 3   {'compound_code': 'Q579+FF New York', 'global_...          2.0     4.3
# 4   {'compound_code': 'J7PW+QP Hewlett, New York',...          NaN     4.7
# 5   {'compound_code': 'Q67H+P9 Bayside, Queens, NY...          2.0     4.4
# 6   {'compound_code': 'V422+H9 New York', 'global_...          NaN     4.5
# 7   {'compound_code': 'P664+7J New York', 'global_...          1.0     3.9
# 8   {'compound_code': 'QXCP+FJ Weehawken, New Jers...          3.0     4.2
# 9   {'compound_code': 'Q43H+95 New York', 'global_...          NaN     4.5
# 10  {'compound_code': 'H2XQ+3M New York', 'global_...          2.0     4.4
# 11  {'compound_code': 'V43M+23 New York', 'global_...          2.0     4.0
# 12  {'compound_code': 'P2F2+3P New York', 'global_...          3.0     4.4
# 13  {'compound_code': 'P858+F3 Franklin Square, Ne...          NaN     4.4
# 14  {'compound_code': 'R23V+68 New York', 'global_...          2.0     4.3
# 15  {'compound_code': 'QXQM+7C West New York, New ...          1.0     4.4
# 16  {'compound_code': 'R8J4+7J Port Washington, Ne...          NaN     4.8
# 17  {'compound_code': 'M25R+82 Brooklyn, New York'...          NaN     4.7
# 18  {'compound_code': 'R375+8H New York', 'global_...          2.0     4.0
# 19  {'compound_code': 'Q244+C9 New York', 'global_...          NaN     4.2
#
#                       reference   scope  \
# 0   ChIJqcy6-hRdwokRdSLrTxc6e8s  GOOGLE
# 1   ChIJjdcjJ2B9wokRTBzKGKs9uLo  GOOGLE
# 2   ChIJeQ7OPtxhwokR0NbauaysWDM  GOOGLE
# 3   ChIJT5fPRAVgwokRApCD3ei8UFQ  GOOGLE
# 4   ChIJWThxmr5lwokRm5Oy36a-7LI  GOOGLE
# 5   ChIJd2gn_99hwokRjFzrReZ66uQ  GOOGLE
# 6   ChIJs7wVgLn1wokRbaji3Nzt9N8  GOOGLE
# 7   ChIJIZ4YNR5hwokR8GxzYqcfnZU  GOOGLE
# 8   ChIJIQkdpDtYwokRtRIP3xnQs2Y  GOOGLE
# 9   ChIJv8YfMdBfwokRGbXaIhS-wLo  GOOGLE
# 10  ChIJxfTWgHhFwokRqp-mL6lnFeg  GOOGLE
# 11  ChIJ_eSjOp_0wokRlY2ZkWUHo8c  GOOGLE
# 12  ChIJt7fMLIlZwokRCRtM9bNDg78  GOOGLE
# 13  ChIJG_4p0MRjwokR-J3YXt3npJU  GOOGLE
# 14  ChIJ-bhM6yL2wokRAtIoWi_TL2k  GOOGLE
# 15  ChIJibl2PxBYwokRCBkiv0UNnLk  GOOGLE
# 16  ChIJ__84a9OIwokR849c3fxlTug  GOOGLE
# 17  ChIJPwg6URNbwokR_YxBHdIupJ8  GOOGLE
# 18  ChIJH97jp3b2wokRyoBwNMM-F9U  GOOGLE
# 19  ChIJXSm3bU9ZwokRKRX6nypuFlQ  GOOGLE
#
#                                                 types  user_ratings_total  \
# 0   [restaurant, meal_takeaway, food, point_of_int...                  42
# 1   [restaurant, food, point_of_interest, establis...                  73
# 2   [restaurant, food, point_of_interest, establis...                 637
# 3   [restaurant, food, point_of_interest, establis...                 243
# 4   [meal_takeaway, bar, restaurant, food, point_o...                 127
# 5   [bar, restaurant, food, point_of_interest, est...                 282
# 6   [restaurant, food, point_of_interest, establis...                  11
# 7   [restaurant, food, point_of_interest, establis...                 524
# 8   [restaurant, food, point_of_interest, establis...                1894
# 9   [restaurant, food, point_of_interest, establis...                  55
# 10  [restaurant, food, point_of_interest, establis...                 265
# 11  [meal_delivery, restaurant, food, point_of_int...                1560
# 12  [bakery, restaurant, food, store, point_of_int...                5933
# 13  [restaurant, food, point_of_interest, establis...                  50
# 14  [restaurant, food, point_of_interest, establis...                3077
# 15  [restaurant, food, point_of_interest, establis...                 265
# 16  [restaurant, food, point_of_interest, establis...                  48
# 17  [restaurant, food, point_of_interest, establis...                 225
# 18  [restaurant, food, point_of_interest, establis...                 382
# 19  [restaurant, bar, food, point_of_interest, est...                 198
#
#                                     vicinity
# 0                  250 Wyckoff Ave, Brooklyn
# 1                      315 Oak St, Uniondale
# 2                20801 Northern Blvd, Queens
# 3                35-25 Farrington St, Queens
# 4                   10 Franklin Ave, Hewlett
# 5                   39-38 Bell Blvd, Bayside
# 6                2051 Webster Ave, The Bronx
# 7              16841 Hillside Avenue, Queens
# 8                 1 County Rd 682, Weehawken
# 9                34-64 Junction Blvd, Queens
# 10           2425 Coney Island Ave, Brooklyn
# 11           2072 White Plains Rd, The Bronx
# 12                    80 Spring St, New York
# 13  1204 Hempstead Turnpike, Franklin Square
# 14                  300 W 114th St, New York
# 15        5904 Bergenline Ave, West New York
# 16              170 Main St, Port Washington
# 17                  67 Fenimore St, Brooklyn
# 18              486 Malcolm X Blvd, New York
# 19                     506 9th Ave, New York
